# %%
import sdmx
import time
# Out:
# /Users/nazimaniltepe/Projects/tuik-sdmx/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
sdmx.add_source({
    "id": "TUIK",
    "url": "https://nsiws.tuik.gov.tr/rest",
    "name": "Türkiye İstatistik Kurumu (TÜİK)"
}, override=True)

# %%
tuik = sdmx.Client('TUIK')

# %%
cat = tuik.categorisation(agency_id='TR')

# %%
cat
# Out:
# <sdmx.StructureMessage>
#   <Header>
#     id: 'IDREF84955'
#     prepared: '2026-04-20T10:12:28.512822+03:00'
#     receiver: <Agency Unknown>
#     sender: <Agency Unknown>
#     source:
#     test: False
#   response: <Response [200]>
#   Categorisation (374): CAT_ATIKSU_ALICI_ORTAM_BELEDIYE_SEBEKE_V2 CAT_B...
#   CategoryScheme (1): CSA_REV1
#   DataflowDefinition (374): DF_ATIKSU_ALICI_ORTAM_BELEDIYE_SEBEKE_V2 DF...

# %%
dte_dfs = [df.artefact.id for df in cat.categorisation.values() if df.category.id == "17.17_2.17_2_2"]

# %%
dte_dfs
# Out:
# ['DF_ALTINSIZ_DTH',
#  'DF_ALTINSIZ_ENERJISIZ_DTH',
#  'DF_ALTINSIZ_ENERJISIZ_IHRACAT_BDE',
#  'DF_ALTINSIZ_ENERJISIZ_IME',
#  'DF_ALTINSIZ_ENERJISIZ_ITHALAT_BDE',
#  'DF_ALTINSIZ_IHRACAT_BDE',
#  'DF_ALTINSIZ_IME',
#  'DF_ALTINSIZ_ITHALAT_BDE',
#  'DF_ALTINSIZ_ITHALAT_ENERJISIZ_ME',
#  'DF_ALTINSIZ_ITHALAT_ME',
#  'DF_DIS_TICARET_HADLERI_V1',
#  'DF_ENERJISIZ_DTH',
#  'DF_ENERJISIZ_IHRACAT_BDE',
#  'DF_ENERJISIZ_IME',
#  'DF_ENERJISIZ_ITHALAT_BDE',
#  'DF_ENERJISIZ_ITHALAT_ME',
#  'DF_IHRACAT_BIRIM_DEGER_V1',
#  'DF_IHRACAT_MIKTAR_ENDEKS_V1',
#  'DF_ITHALAT_BIRIM_DEGER_ENDEKSI_V1',
#  'DF_ITHALAT_MIKTAR_ENDEKS_V1',
#  'DF_TAKVIM_ETKISINDEN_ARINDIRILMIS_IHRACAT_V2',
#  'DF_TAKVIM_ETKISINDEN_ARINDIRILMIS_ITHALAT_V2']

# %%
ydufe_dfs = [df.artefact.id for df in cat.categorisation.values() if df.category.id == "6.6_6"]

# %%
ydufe_dfs
# Out:
# ['DF_YDUFE_EDO_V1']

# %%
tgfe_dfs = [df.artefact.id for df in cat.categorisation.values() if df.category.id == "6.6_4"]

# %%
tgfe_dfs
# Out:
# ['DF_TARIMSAL_GIRDI_FIYAT_ENDEKSI_DEGISIM_V2']
