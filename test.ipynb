# %%
import sdmx
import time
import numpy as np
import pendulum

# %%
sdmx.add_source({
    "id": "TUIK",
    "url": "https://nsiws.tuik.gov.tr/rest",
    "name": "Türkiye İstatistik Kurumu (TÜİK)"
}, override=True)

# %%
df = 'DF_YDUFE_EDO'
tuik = sdmx.Client('TUIK')
